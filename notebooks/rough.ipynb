# %%
import os
from dotenv import load_dotenv
from pathlib import Path
from src.ingestion.pdf_parser import parse_pdf
from src.ingestion.chunker import load_and_chunk_pdf
from src.ingestion.embedder import embed_texts
from src.ingestion.ingest_pipeline import run_ingestion
from src.retrieval.retriever import retrieve
from src.retrieval.reranker import rerank
from src.retrieval.vector_store import VectorStore
from src.evaluation.evaluator import evaluate_rag

# %%
load_dotenv()
ROOT = Path(os.getenv("PYTHONPATH"))
# Resolve path from project root (notebook often runs with cwd = notebooks/)
ROOT = Path.cwd()
if not (ROOT / "uploaded_pdfs").exists():
    ROOT = ROOT.parent

# %% [markdown]
# To check the papers in the database

# %%
from src.retrieval.vector_store import VectorStore

store = VectorStore()
papers = store.list_papers_with_info()
for p in papers:
    print(p)

# %% [markdown]
# For ml ops and 10 different test

# %% [markdown]
# # Test 1 - Baseline

# %%
import sys
import os
from pathlib import Path
from dotenv import load_dotenv

load_dotenv(override=True)

ROOT = Path(os.getenv("PYTHONPATH"))
sys.path.insert(0, str(ROOT))

# %%
from src.evaluation.experiment_log import run_experiment

scores = run_experiment(
    run_name="run_01_baseline",
    model="openai/gpt-4o-mini",
    chunk_size=500,
    chunk_overlap=50,
    reranker="sbert",
    rerank_n=5,
    use_langgraph=False,
    notes="Baseline",
)

# %%
import mlflow
print(mlflow.get_tracking_uri())

# %%
import os
os.listdir("/Users/muralikrishnagurijala/Desktop/My_RAG/notebooks")

# %% [markdown]
# # Test 2 chunks size 200, overlap 20

# %%
import sys
import os
from pathlib import Path
from dotenv import load_dotenv
import mlflow

load_dotenv(override=True)

ROOT = Path(os.getenv("PYTHONPATH"))
sys.path.insert(0, str(ROOT))

print(mlflow.get_tracking_uri())

# %%
from src.evaluation.experiment_log import run_experiment

scores = run_experiment(
    run_name="run_02_chunk_200",
    model="openai/gpt-4o-mini",
    chunk_size=200,
    chunk_overlap=20,
    reranker="sbert",
    rerank_n=5,
    use_langgraph=False,
    notes="chunk_size=200, overlap=20",
)

# %% [markdown]
# # Test 3 Chunk_size 750 and overlap 75

# %%
import sys
import os
from pathlib import Path
from dotenv import load_dotenv
import mlflow

load_dotenv(override=True)

ROOT = Path(os.getenv("PYTHONPATH"))
sys.path.insert(0, str(ROOT))

print(mlflow.get_tracking_uri())

# %%
from src.evaluation.experiment_log import run_experiment

scores = run_experiment(
    run_name="run_03_chunk_750",
    model="openai/gpt-4o-mini",
    chunk_size=750,
    chunk_overlap=75,
    reranker="sbert",
    rerank_n=5,
    use_langgraph=False,
    notes="chunk_size=750, overlap=75",
)

# %% [markdown]
# # Test 4 chunk size 1000 and overlap 50

# %%
import sys
import os
from pathlib import Path
from dotenv import load_dotenv
import mlflow

load_dotenv(override=True)

ROOT = Path(os.getenv("PYTHONPATH"))
sys.path.insert(0, str(ROOT))

print(mlflow.get_tracking_uri())

# %%
from src.evaluation.experiment_log import run_experiment

scores = run_experiment(
    run_name="run_04_chunk_1000",
    model="openai/gpt-4o-mini",
    chunk_size=1000,
    chunk_overlap=50,
    reranker="sbert",
    rerank_n=5,
    use_langgraph=False,
    notes="chunk_size=1000, overlap=50",
)

# %% [markdown]
# # Test 5 chunk size 500 and overlap 150

# %%
import sys
import os
from pathlib import Path
from dotenv import load_dotenv
import mlflow

load_dotenv(override=True)

ROOT = Path(os.getenv("PYTHONPATH"))
sys.path.insert(0, str(ROOT))

print(mlflow.get_tracking_uri())

# %%
from src.evaluation.experiment_log import run_experiment

scores = run_experiment(
    run_name="run_05_overlap_150",
    model="openai/gpt-4o-mini",
    chunk_size=500,
    chunk_overlap=150,
    reranker="sbert",
    rerank_n=5,
    use_langgraph=False,
    notes="chunk_size=500, overlap=150",
)

# %% [markdown]
# # Test 6 cohere reranker

# %%
import sys
import os
from pathlib import Path
from dotenv import load_dotenv
import mlflow

load_dotenv(override=True)

ROOT = Path(os.getenv("PYTHONPATH"))
sys.path.insert(0, str(ROOT))

print(mlflow.get_tracking_uri())

# %%
from src.evaluation.experiment_log import run_experiment

scores = run_experiment(
    run_name="run_06_cohere_reranker",
    model="openai/gpt-4o-mini",
    chunk_size=500,
    chunk_overlap=50,
    reranker="cohere",
    rerank_n=5,
    use_langgraph=False,
    notes="Cohere reranker vs SBERT baseline",
)

# %% [markdown]
# # Test 7 claude model

# %%
import sys
import os
from pathlib import Path
from dotenv import load_dotenv
import mlflow

load_dotenv(override=True)

ROOT = Path(os.getenv("PYTHONPATH"))
sys.path.insert(0, str(ROOT))

print(mlflow.get_tracking_uri())

# %%
from src.evaluation.experiment_log import run_experiment

scores = run_experiment(
    run_name="run_07_claude_haiku",
    model="anthropic/claude-haiku-4-5-20251001",
    chunk_size=500,
    chunk_overlap=50,
    reranker="sbert",
    rerank_n=5,
    use_langgraph=False,
    notes="Claude Haiku vs GPT-4o-mini baseline",
)

# %% [markdown]
# # Test 8 rerank = 3

# %%
import sys
import os
from pathlib import Path
from dotenv import load_dotenv
import mlflow

load_dotenv(override=True)

ROOT = Path(os.getenv("PYTHONPATH"))
sys.path.insert(0, str(ROOT))

print(mlflow.get_tracking_uri())

# %%
from src.evaluation.experiment_log import run_experiment

scores = run_experiment(
    run_name="run_08_rerank_n_3",
    model="openai/gpt-4o-mini",
    chunk_size=500,
    chunk_overlap=50,
    reranker="sbert",
    rerank_n=3,
    use_langgraph=False,
    notes="rerank_n=3, fewer chunks to LLM",
)

# %% [markdown]
# # Test 9 rerank = 7

# %%
import sys
import os
from pathlib import Path
from dotenv import load_dotenv
import mlflow

load_dotenv(override=True)

ROOT = Path(os.getenv("PYTHONPATH"))
sys.path.insert(0, str(ROOT))

print(mlflow.get_tracking_uri())

# %%
from src.evaluation.experiment_log import run_experiment

scores = run_experiment(
    run_name="run_09_rerank_n_7",
    model="openai/gpt-4o-mini",
    chunk_size=500,
    chunk_overlap=50,
    reranker="sbert",
    rerank_n=7,
    use_langgraph=False,
    notes="rerank_n=7, more chunks to LLM",
)

# %% [markdown]
# # Test 10 lang_graph

# %%
import sys
import os
from pathlib import Path
from dotenv import load_dotenv
import mlflow

load_dotenv(override=True)

ROOT = Path(os.getenv("PYTHONPATH"))
sys.path.insert(0, str(ROOT))

print(mlflow.get_tracking_uri())

# %%
from src.evaluation.experiment_log import run_experiment

scores = run_experiment(
    run_name="run_10_langgraph",
    model="openai/gpt-4o-mini",
    chunk_size=500,
    chunk_overlap=50,
    reranker="sbert",
    rerank_n=5,
    use_langgraph=True,
    notes="LangGraph query rewriting ON",
)

# %% [markdown]
# # Testing some question in langgraph pipeline

# %%
from src.graph.rag_graph import rag_pipeline

state = rag_pipeline.invoke({
    "question": "What are the three main components of an Agentic RAG system?",
    "original_question": "What are the three main components of an Agentic RAG system?",
    "chunks": [],
    "reranked": [],
    "source_chunks": [],
    "answer": "",
    "retries": 0,
    "quality_passed": False,
})

print(state.get("error"))
print(state.get("answer"))

# %%
from src.generation.llm_router import generate

question = "What are the three main components of an Agentic RAG system?"
prompt = (
    "Is this question related to artificial intelligence, machine learning, or academic research topics? "
    "Reply with only 'yes' or 'no'.\n\n"
    f"Question: {question}"
)
response = generate(prompt, model="openai")
print(repr(response))

# %%
print(type(response))
print(repr(response))

# %%
from src.graph.nodes import intent_check_node

state = {"question": "What are the three main components of an Agentic RAG system?"}
result = intent_check_node(state)
print(result)

# %% [markdown]
# # Test 10 after the fixed version of lang_graph

# %% [markdown]
# Because of the 0.7 temp which is baseline for gpt model the intent check always halucinates a little so we chnaged it 0 so that it will give almost same yes or no everytime and improved the promt a little

# %%
import sys
import os
from pathlib import Path
from dotenv import load_dotenv
import mlflow

load_dotenv(override=True)

ROOT = Path(os.getenv("PYTHONPATH"))
sys.path.insert(0, str(ROOT))

print(mlflow.get_tracking_uri())

# %%
from src.evaluation.experiment_log import run_experiment

scores = run_experiment(
    run_name="run_10_langgraph_fixed",
    model="openai/gpt-4o-mini",
    chunk_size=500,
    chunk_overlap=50,
    reranker="sbert",
    rerank_n=5,
    use_langgraph=True,
    notes="LangGraph fixed - intent check temperature=0 and neutral system prompt",
)

# %% [markdown]
# # Test 11 Langgraph  with Chunksize 750 and overlap 75

# %%
import sys
import os
from pathlib import Path
from dotenv import load_dotenv
import mlflow

load_dotenv(override=True)

ROOT = Path(os.getenv("PYTHONPATH"))
sys.path.insert(0, str(ROOT))

print(mlflow.get_tracking_uri())

# %%
from src.evaluation.experiment_log import run_experiment

scores = run_experiment(
    run_name="run_11_langgraph_chunk_750",
    model="openai/gpt-4o-mini",
    chunk_size=750,
    chunk_overlap=75,
    reranker="sbert",
    rerank_n=5,
    use_langgraph=True,
    notes="LangGraph with chunk_size=750, overlap=75",
)
