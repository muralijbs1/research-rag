# %% [markdown]
# To test the embedding vectors

# %%
from src.ingestion.embedder import embed_texts

sentences = [
    "I am writting the first sentence.",
    "Here is another one.",
    "RAG systems combine retrieval and generation thats why its called RAG."
]

# Returns List[List[float]] – one vector per sentence
vectors = embed_texts(sentences)

print(len(vectors))          
print(len(vectors[0]))       
print(vectors[0][:5])
