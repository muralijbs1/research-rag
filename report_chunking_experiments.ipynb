# %% [markdown]
# # Chunking Strategy Experiment
#
# In this notebook I test different chunk sizes on the same paper with the same questions.
# The goal is to find the chunk size that gives the best retrieval quality.

# %%
from IPython.display import Markdown, display

# %%
import importlib
import src.ingestion.chunker as chunker

importlib.reload(chunker)
from src.ingestion.chunker import load_and_chunk_pdf

# %%
chunks = load_and_chunk_pdf("uploaded_pdfs/Attention_is _all_you_need.pdf",200,20)
print(f"Total chunks: {len(chunks)}")
display(Markdown(chunks[0]))

# %%
display(Markdown(chunks[1]))
display(Markdown(chunks[2]))

# %%
chunks = load_and_chunk_pdf("uploaded_pdfs/Attention_is _all_you_need.pdf")
print(f"Total chunks: {len(chunks)}")
display(Markdown(chunks[0]))
# Out:
# Total chunks: 88
# Provided proper attribution is provided, Google hereby grants permission to reproduce the tables and figures in this paper solely for use in journalistic or scholarly works. Attention Is All You Need Ashish Vaswani∗ Google Brain avaswani@google.com Noam Shazeer∗ Google Brain noam@google.com Niki Parmar∗ Google Research nikip@google.com Jakob Uszkoreit∗ Google Research usz@google.com Llion Jones∗ Google Research llion@google.com Aidan N. Gomez∗† University of Toronto aidan@cs.toronto.edu Łukasz K

# %%
chunks = load_and_chunk_pdf("uploaded_pdfs/Attention_is _all_you_need.pdf",2000,0)
print(f"Total chunks: {len(chunks)}")
display(Markdown(chunks[0]))
display(Markdown(chunks[1]))
# Out:
# Total chunks: 20
# ...

# %%
chunks = load_and_chunk_pdf("uploaded_pdfs/Attention_is _all_you_need.pdf",2000,10)
print(f"Total chunks: {len(chunks)}")
display(Markdown(chunks[0]))
display(Markdown(chunks[1]))
# Out:
# Total chunks: 20
# ...
